# %% [markdown]
# <a href="https://colab.research.google.com/github/scienceguy19/PHSX/blob/main/zach_projectile_motion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#PHSX 216 & 218 plotting code
#Brianna Beller
#Updated September 2023

import numpy as np
import matplotlib.pyplot as plt


# %matplotlib inline

#-----------------------------------------------------------------------#
#Data Section - Create Arrays for data. Perform necessary calculations.
#CHANGE THE VARIABLE NAMES and numbers to match your data

angle_launched = np.array([36, 30, 33, 39, 42]) #what are units?
final_height = np.array([.518, .409, .484, .616, .566]) #what are units?

#-----------------------------------------------------------------------#
#Create array for uncertainties in y variable
#CHANGE THE VARIABLE NAME and numbers to match your data

err_final_height = np.array([1.5,.97,1.2,1.3,.9,1.4,.87])

#-----------------------------------------------------------------------#
#--------------------------Plotting Code Below--------------------------#
#-----------------------------------------------------------------------#

#UPDATE THIS SECTION!!!

#Re-assign variables as x, y, dy so that the remaining plotting code may remain generic
x = angle_launched             #this should be the array you want to plot on the x axis
y = final_height             #this should be the array you want to plot on the y axis
dy = err_final_height       #this should be your error in y array


#update each of these 4 strings
plot_title= 'Angle Launched vs Final Height'
x_label= 'Angle Launched'
y_label= 'Final Height(m)'


#-----------------------------------------------------------------------#
#Don't need to change anything in this section!


#size the plot
plt.figure(figsize=(15,10))

#create scatter plot
plt.scatter(x, y, color='blue', marker='o')

#create labels
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(plot_title)

#fitting to a 2nd degree polynomial
c,b,a=np.polynomial.polynomial.polyfit(x,y,2,w=dy)

#Annotate with values of A, B, C from best fit polynomial
plt.annotate('A = {value:.{digits}E}'.format(value=a, digits=3),
             (0.05, 0.9), xycoords='axes fraction')

plt.annotate('B = {value:.{digits}E}'.format(value=b, digits=3),
             (0.05, 0.85), xycoords='axes fraction')

plt.annotate('C = {value:.{digits}E}'.format(value=c, digits=3),
             (0.05, 0.8), xycoords='axes fraction')
#Create fit line
xnew = np.linspace(x.min(), x.max(), 300)
fit = a*xnew**2 + b*xnew +c

plt.plot(xnew, fit, color='green')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-7744dc4f4141> in <cell line: 58>()
#      56
#      57 #fitting to a 2nd degree polynomial
# ---> 58 c,b,a=np.polynomial.polynomial.polyfit(x,y,2,w=dy)
#      59
#      60 #Annotate with values of A, B, C from best fit polynomial
#
# /usr/local/lib/python3.10/dist-packages/numpy/polynomial/polynomial.py in polyfit(x, y, deg, rcond, full, w)
#    1360
#    1361     """
# -> 1362     return pu._fit(polyvander, x, y, deg, rcond, full, w)
#    1363
#    1364
#
# /usr/local/lib/python3.10/dist-packages/numpy/polynomial/polyutils.py in _fit(vander_f, x, y, deg, rcond, full, w)
#     640             raise TypeError("expected 1D vector for w")
#     641         if len(x) != len(w):
# --> 642             raise TypeError("expected x and w to have same length")
#     643         # apply weights. Don't use inplace operations as they
#     644         # can cause problems with NA.
#
# TypeError: expected x and w to have same length
